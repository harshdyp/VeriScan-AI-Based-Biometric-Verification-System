# %%
# SmartID Evaluation

Lightweight notebook to illustrate sample similarity scores and OCR extraction on example images.

# %%
import os
from smartid.ocr.extract_text import extract_text_from_image

# Inspect OCR output on example image if present
img_path = 'temp_id.jpg' if os.path.exists('temp_id.jpg') else None
if img_path:
    print('OCR text sample:')
    print(extract_text_from_image(img_path)[:500])
else:
    print('Place an ID image at temp_id.jpg to preview OCR output.')
